# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
arr=np.random.randn(1000).reshape(500,2)

# %%
df=pd.DataFrame(arr)

# %%
df.columns=['A','B']

# %%
df
# Out:
#             A         B
# 0    1.359675  0.523990
# 1   -0.120652  0.124291
# 2    0.096559 -1.417238
# 3   -0.663276 -1.046680
# 4    1.446129 -1.436352
# ..        ...       ...
# 495  2.479697  0.301003
# 496  0.115511 -0.361743
# 497  0.155692 -1.171344
# 498  0.101572 -0.162152
# 499 -0.975935  0.567591
#
# [500 rows x 2 columns]

# %%
a=np.random.randint(0,10,10)
b=np.random.randint(0,10,10)
c=np.random.randint(0,10,10)

# %%
#scatter plot
plt.scatter(a,b,c='red',marker='o' , s=50,label='A,B')
plt.scatter(a,c,c='green',marker='s' , s=50,label='A,C')
plt.title("Scatter plot")
plt.xlabel("$X$ axis")
plt.ylabel("$Y$ axis")
plt.legend()
plt.show()

# %%
#line plot
plt.plot(a,b,c='red',linestyle="--",marker='s',label='A,B')
plt.plot(a,c,c='green',marker='o',label='A,C')
plt.title("Line plot")
plt.xlabel("$X$ axis")
plt.ylabel("$Y$ axis")
plt.legend()
plt.show()

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data = load_boston()

# %%
data
# Out:
# {'data': array([[6.3200e-03, 1.8000e+01, 2.3100e+00, ..., 1.5300e+01, 3.9690e+02,
#          4.9800e+00],
#         [2.7310e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9690e+02,
#          9.1400e+00],
#         [2.7290e-02, 0.0000e+00, 7.0700e+00, ..., 1.7800e+01, 3.9283e+02,
#          4.0300e+00],
#         ...,
#         [6.0760e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          5.6400e+00],
#         [1.0959e-01, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9345e+02,
#          6.4800e+00],
#         [4.7410e-02, 0.0000e+00, 1.1930e+01, ..., 2.1000e+01, 3.9690e+02,
#          7.8800e+00]]),
#  'target': array([24. , 21.6, 34.7, 33.4, 36.2, 28.7, 22.9, 27.1, 16.5, 18.9, 15. ,
#         18.9, 21.7, 20.4, 18.2, 19.9, 23.1, 17.5, 20.2, 18.2, 13.6, 19.6,
#         15.2, 14.5, 15.6, 13.9, 16.6, 14.8, 18.4, 21. , 12.7, 14.5, 13.2,
#         13.1, 13.5, 18.9, 20. , 21. , 24.7, 30.8, 34.9, 26.6, 25.3, 24.7,
# ...

# %%
plt.hist(data.target)
plt.xlabel('price')
plt.ylabel('count')
plt.show()

# %%
X = data['data']
y = data['target']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-1.12386867e-01,  5.80587074e-02,  1.83593559e-02,  2.12997760e+00,
#        -1.95811012e+01,  3.09546166e+00,  4.45265228e-03, -1.50047624e+00,
#         3.05358969e-01, -1.11230879e-02, -9.89007562e-01,  7.32130017e-03,
#        -5.44644997e-01])

# %%
lr.intercept_
# Out:
# 42.93352585337672

# %%
lr.score(X_train, y_train)
# Out:
# 0.7293585058196337

# %%
lr.score(X_test,y_test)
# Out:
# 0.763417443213847

# %%
print(f"Original Value from test at 0th index: ", y_test[0])
# Out:
# Original Value from test at 0th index:  28.2

# %%
sample = X_test[0]

# %%
lr.predict([sample])
# Out:
# array([32.65503184])
